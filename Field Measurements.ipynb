# %% [markdown]
# This study shows the different pH levels of all the canals and reservoirs that we use here in Phoenix. We are taking data from the following areas:
#     AZ Canal, CAP Canal, Chandler, Mesa Turnout, Salt River, Tempe, Verde River
#
# pH levels are affected by temperature. The higher the temperature, the pH level drops.
#
# A safe pH level for drinking water is between 6 and 8.5.
#
# High pH water tastes like baking soda and leaves residue on fixtures. The water is also hard. It doesn't cause any health risks, but can be hard to lather with soap, can cause skin problems, and is more difficult to heat up.
#
# Low pH water can have a bitter taste and may cause corrosion on fixtures. It can be unsafe to drink because it can be contaminated with pollutants.

# %%
#Dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Import the CSV file

field = "Field_Measurements.csv"
field_df = pd.read_csv(field)

field_df
# Out:
#       site number                            site location Cluster  \
# 0              R5  Verde River btwn Horseshoe and Bartlett   verde
# 1           R6-10           Bartlett Reservoir near outlet   verde
# 2           R6-15           Bartlett Reservoir near outlet   verde
# 3           R6-20           Bartlett Reservoir near outlet   verde
# 4           R6-25           Bartlett Reservoir near outlet   verde
# ...           ...                                      ...     ...
# 14723     Roos-35               Roosevelt Lake near outlet    salt
# 14724     Roos-40               Roosevelt Lake near outlet    salt
# 14725     Roos-45               Roosevelt Lake near outlet    salt
# 14726      Roos-5               Roosevelt Lake near outlet    salt
# 14727     Roos-50               Roosevelt Lake near outlet    salt
#
#              site acronym  date  depth (m)  T (C)  DO (mg/l)  pH  \
# 0      verde abv bartlett  1999        0.0    NaN        NaN NaN
# ...

# %%
field_df.count()
# Out:
# site number          14728
# site location        14728
# Cluster              14252
# site acronym         14728
# date                 14728
# depth (m)             7651
# T (C)                 7535
# DO (mg/l)             5306
# pH                    3855
# Secchi Disk (m)        422
# samples collected      496
# comments                79
# dtype: int64

# %%
#Clean up the data

field_cleanup = field_df [["site number", "site location", "Cluster", "depth (m)", "date", "T (C)", "DO (mg/l)", "pH"]]
field_cleanup = field_cleanup.dropna()

# %%
field_cleanup.count()
# Out:
# site number      1736
# site location    1736
# Cluster          1736
# depth (m)        1736
# date             1736
# T (C)            1736
# DO (mg/l)        1736
# pH               1736
# dtype: int64

# %%
#Show the new information

field_cleanup
# Out:
#       site number                     site location Cluster  depth (m)  date  \
# 95             R1     CAP canal above Waddell Canal     cap        0.0  1999
# 106            R3                     Waddell Canal     cap        0.0  1999
# 107            R4              Cap Canal at 7th St.     cap        0.0  1999
# 109           R12  AZ Canal above CAP Cross-connect     srp        0.0  1999
# 110           R13  AZ Canal below CAP Cross-connect     srp        0.0  1999
# ...           ...                               ...     ...        ...   ...
# 12141          R2   Lake Pleasant integrated sample     cap       11.4  2011
# 12142          R2   Lake Pleasant integrated sample     cap        8.0  2011
# 12143          R2   Lake Pleasant integrated sample     cap        4.8  2011
# 12144          R2   Lake Pleasant integrated sample     cap        1.6  2011
# 12145          R2   Lake Pleasant integrated sample     cap        1.2  2011
#
#        T (C)  DO (mg/l)    pH
# ...

# %%
#Create a scatter plot showing the correlation of the temperature vs the pH level

temp_x = field_cleanup['pH'];
temp_y = field_cleanup['T (C)']

# %%
plt.figure(figsize=(20,14))
plt.title('pH Levels at Different Temperatures')
plt.xlabel('pH');
plt.ylabel('Temperature (C)')

plt.scatter (temp_x,temp_y)
#plt.savefig('field measurements.png')

# %% [markdown]
# This data shows that fortunately, with the rise in temperature, we are not seeing a difference in pH levels. The levels are staying consistent for the most part despite the temperature of the water

# %%
#Create a scatter plot that shows the pH levels over time

year_x = field_cleanup ['date'];
year_y = field_cleanup['pH']

# %%
plt.figure(figsize=(20,20))
plt.title('pH Levels by Year')
plt.xlabel('Year')
plt.ylabel('pH')


plt.scatter (year_x, year_y)
#plt.savefig('pH.png')

# %% [markdown]
# Here, we are seeing in recent years that the pH levels stayed consistent between 6 and 8.5, with only a few instances of going a little bit higher. However, in the early 2000's, there were multiple instances where the pH level fell very low.
